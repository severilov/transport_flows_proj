# %% [markdown]
# ## Data Initializing

# %%
import pandas as pd
import numpy as np
import data_handler as dh
import model as md
import time
import matplotlib.pyplot as plt
from matplotlib import rc
import pickle

# %%
import importlib
importlib.reload(dh)
importlib.reload(md)
# Out:
# <module 'model' from '/Users/kate/PycharmProjects/TransportNet-master/Stable Dynamic & Beckman/model.py'>

# %%
import numba
numba.__version__
# Out:
# '0.48.0'

# %% [markdown]
# # Stable Dynamics Model
#
# parameter $\mu = 0$

# %%
net_name = 'Custom_net.tntp'
trips_name = 'Custom_trips.tntp'

sd_save = 'stable_dynamics_results/'
# net_name = 'Anaheim_net.tntp'
# trips_name = 'Anaheim_trips.tntp'

# %%
handler = dh.DataHandler()
graph_correspondences, total_od_flow = handler.GetGraphCorrespondences(trips_name)
graph_data = handler.GetGraphData(net_name, 
                                  columns = ['init_node', 'term_node', 
                                             'capacity', 'free_flow_time'])
init_capacities = graph_data['graph_table']['capacity'] #* 2.5

# %% [markdown]
# ## Base flows
# First of all, we should find admissible set of flows on the transport graph. It is required for defining duality gap.

# %%
alpha = 0.75
# graph_data['graph_table']['capacity'] = init_capacities * alpha
model = md.Model(graph_data, graph_correspondences,
                 total_od_flow, mu = 0)

graph_data['graph_table'].head()
# Out:
#    init_node  init_node_thru  term_node  term_node_thru  capacity  \
# 0          1            True          2            True    2000.0
# 1          1            True          2            True    2000.0
# 2          2            True          1            True    2000.0
# 3          2            True          1            True    2000.0
#
#    free_flow_time
# 0             1.0
# 1             0.5
# 2             1.0
# 3             0.5

# %%
graph_correspondences
# Out:
# {1: {'targets': [1, 2], 'corrs': [0.0, 3000.0]},
#  2: {'targets': [2, 1], 'corrs': [0.0, 3000.0]}}

# %% [raw]
# handler = dh.DataHandler()
# net_name = 'Custom_net.tntp'
# trips_name = 'Custom_trips.tntp'
# graph_correspondences_2, _ = handler.GetGraphCorrespondences(trips_name)

# %% [raw]
# type(graph_correspondences_2[2]['corrs'][0])

# %%
assert(model.mu == 0)
max_iter = 20000

solver_kwargs = {'eps': 1e-4,
                 'max_iter': max_iter, 'stop_crit': 'max_iter',
                 'verbose': True, 'verbose_step': 200, 'save_history': True}
tic = time.time()
result = model.find_equilibrium(solver_name = '', composite = True,
                            solver_kwargs = solver_kwargs,
                            base_flows = alpha * graph_data['graph_table']['capacity'])
                            #base_flows here doesnt define anything now
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
print('Time ratio =', 
      np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
print('Flow excess =', 
      np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')

result['elapsed_time'] = toc - tic

base_flows = result['flows']
# Out:
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = 300
#
# Iterations number: 200
# Inner iterations number: 432
# Primal_func_value = 3000
# Dual_func_value = -4353.86
# Duality_gap = -1053.86
# Duality_gap / Duality_gap_init = -3.51288
#
# Iterations number: 400
# Inner iterations number: 832
# Primal_func_value = 3000
# Dual_func_value = -4353.32
# Duality_gap = -1053.32
# Duality_gap / Duality_gap_init = -3.51107
#
# Iterations number: 600
# Inner iterations number: 1232
# Primal_func_value = 3000
# Dual_func_value = -4352.78
# Duality_gap = -1052.78
# Duality_gap / Duality_gap_init = -3.50925
#
# Iterations number: 800
# Inner iterations number: 1632
# Primal_func_value = 3000
# Dual_func_value = -4352.23
# Duality_gap = -1052.23
# Duality_gap / Duality_gap_init = -3.50744
#
# Iterations number: 1000
# Inner iterations number: 2032
# Primal_func_value = 3000
# Dual_func_value = -4351.69
# Duality_gap = -1051.69
# Duality_gap / Duality_gap_init = -3.50562
#
# Iterations number: 1200
# Inner iterations number: 2432
# Primal_func_value = 3000
# Dual_func_value = -4351.14
# Duality_gap = -1051.14
# Duality_gap / Duality_gap_init = -3.5038
#
# Iterations number: 1400
# Inner iterations number: 2832
# Primal_func_value = 3000
# Dual_func_value = -4350.59
# Duality_gap = -1050.59
# Duality_gap / Duality_gap_init = -3.50198
#
# Iterations number: 1600
# Inner iterations number: 3232
# Primal_func_value = 3000
# Dual_func_value = -4350.05
# Duality_gap = -1050.05
# Duality_gap / Duality_gap_init = -3.50015
#
# Iterations number: 1800
# Inner iterations number: 3632
# Primal_func_value = 3000
# Dual_func_value = -4349.5
# Duality_gap = -1049.5
# Duality_gap / Duality_gap_init = -3.49832
#
# Iterations number: 2000
# Inner iterations number: 4032
# Primal_func_value = 3000
# Dual_func_value = -4348.95
# Duality_gap = -1048.95
# Duality_gap / Duality_gap_init = -3.49649
#
# Iterations number: 2200
# Inner iterations number: 4432
# Primal_func_value = 3000
# Dual_func_value = -4348.4
# Duality_gap = -1048.4
# Duality_gap / Duality_gap_init = -3.49466
#
# Iterations number: 2400
# Inner iterations number: 4832
# Primal_func_value = 3000
# Dual_func_value = -4347.85
# Duality_gap = -1047.85
# Duality_gap / Duality_gap_init = -3.49282
#
# Iterations number: 2600
# Inner iterations number: 5232
# Primal_func_value = 3000
# Dual_func_value = -4347.3
# Duality_gap = -1047.3
# Duality_gap / Duality_gap_init = -3.49098
#
# Iterations number: 2800
# Inner iterations number: 5632
# Primal_func_value = 3000
# Dual_func_value = -4346.74
# Duality_gap = -1046.74
# Duality_gap / Duality_gap_init = -3.48914
#
# Iterations number: 3000
# Inner iterations number: 6032
# Primal_func_value = 3000
# Dual_func_value = -4346.19
# Duality_gap = -1046.19
# Duality_gap / Duality_gap_init = -3.4873
#
# Iterations number: 3200
# Inner iterations number: 6432
# Primal_func_value = 3000
# Dual_func_value = -4345.64
# Duality_gap = -1045.64
# Duality_gap / Duality_gap_init = -3.48545
#
# Iterations number: 3400
# Inner iterations number: 6832
# Primal_func_value = 3000
# Dual_func_value = -4345.08
# Duality_gap = -1045.08
# Duality_gap / Duality_gap_init = -3.4836
#
# Iterations number: 3600
# Inner iterations number: 7232
# Primal_func_value = 3000
# Dual_func_value = -4344.53
# Duality_gap = -1044.53
# Duality_gap / Duality_gap_init = -3.48175
#
# Iterations number: 3800
# Inner iterations number: 7632
# Primal_func_value = 3000
# Dual_func_value = -4343.97
# Duality_gap = -1043.97
# Duality_gap / Duality_gap_init = -3.4799
#
# Iterations number: 4000
# Inner iterations number: 8032
# Primal_func_value = 3000
# Dual_func_value = -4343.41
# Duality_gap = -1043.41
# Duality_gap / Duality_gap_init = -3.47804
#
# Iterations number: 4200
# Inner iterations number: 8432
# Primal_func_value = 3000
# Dual_func_value = -4342.85
# Duality_gap = -1042.85
# Duality_gap / Duality_gap_init = -3.47618
#
# Iterations number: 4400
# Inner iterations number: 8832
# Primal_func_value = 3000
# Dual_func_value = -4342.3
# Duality_gap = -1042.3
# Duality_gap / Duality_gap_init = -3.47432
#
# Iterations number: 4600
# Inner iterations number: 9232
# Primal_func_value = 3000
# Dual_func_value = -4341.74
# Duality_gap = -1041.74
# Duality_gap / Duality_gap_init = -3.47245
#
# Iterations number: 4800
# Inner iterations number: 9632
# Primal_func_value = 3000
# Dual_func_value = -4341.18
# Duality_gap = -1041.18
# Duality_gap / Duality_gap_init = -3.47058
#
# Iterations number: 5000
# Inner iterations number: 10032
# Primal_func_value = 3000
# Dual_func_value = -4340.61
# Duality_gap = -1040.61
# Duality_gap / Duality_gap_init = -3.46871
#
# Iterations number: 5200
# Inner iterations number: 10432
# Primal_func_value = 3000
# Dual_func_value = -4340.05
# Duality_gap = -1040.05
# Duality_gap / Duality_gap_init = -3.46684
#
# Iterations number: 5400
# Inner iterations number: 10832
# Primal_func_value = 3000
# Dual_func_value = -4339.49
# Duality_gap = -1039.49
# Duality_gap / Duality_gap_init = -3.46497
#
# Iterations number: 5600
# Inner iterations number: 11232
# Primal_func_value = 3000
# Dual_func_value = -4338.93
# Duality_gap = -1038.93
# Duality_gap / Duality_gap_init = -3.46309
#
# Iterations number: 5800
# Inner iterations number: 11632
# Primal_func_value = 3000
# Dual_func_value = -4338.36
# Duality_gap = -1038.36
# Duality_gap / Duality_gap_init = -3.46121
#
# Iterations number: 6000
# Inner iterations number: 12032
# Primal_func_value = 3000
# Dual_func_value = -4337.8
# Duality_gap = -1037.8
# Duality_gap / Duality_gap_init = -3.45933
#
# Iterations number: 6200
# Inner iterations number: 12432
# Primal_func_value = 3000
# Dual_func_value = -4337.23
# Duality_gap = -1037.23
# Duality_gap / Duality_gap_init = -3.45744
#
# Iterations number: 6400
# Inner iterations number: 12832
# Primal_func_value = 3000
# Dual_func_value = -4336.67
# Duality_gap = -1036.67
# Duality_gap / Duality_gap_init = -3.45555
#
# Iterations number: 6600
# Inner iterations number: 13232
# Primal_func_value = 3000
# Dual_func_value = -4336.1
# Duality_gap = -1036.1
# Duality_gap / Duality_gap_init = -3.45366
#
# Iterations number: 6800
# Inner iterations number: 13632
# Primal_func_value = 3000
# Dual_func_value = -4335.53
# Duality_gap = -1035.53
# Duality_gap / Duality_gap_init = -3.45177
#
# Iterations number: 7000
# Inner iterations number: 14032
# Primal_func_value = 3000
# Dual_func_value = -4334.96
# Duality_gap = -1034.96
# Duality_gap / Duality_gap_init = -3.44987
#
# Iterations number: 7200
# Inner iterations number: 14432
# Primal_func_value = 3000
# Dual_func_value = -4334.39
# Duality_gap = -1034.39
# Duality_gap / Duality_gap_init = -3.44797
#
# Iterations number: 7400
# Inner iterations number: 14832
# Primal_func_value = 3000
# Dual_func_value = -4333.82
# Duality_gap = -1033.82
# Duality_gap / Duality_gap_init = -3.44607
#
# Iterations number: 7600
# Inner iterations number: 15232
# Primal_func_value = 3000
# Dual_func_value = -4333.25
# Duality_gap = -1033.25
# Duality_gap / Duality_gap_init = -3.44417
#
# Iterations number: 7800
# Inner iterations number: 15632
# Primal_func_value = 3000
# Dual_func_value = -4332.68
# Duality_gap = -1032.68
# Duality_gap / Duality_gap_init = -3.44226
#
# Iterations number: 8000
# Inner iterations number: 16032
# Primal_func_value = 3000
# Dual_func_value = -4332.11
# Duality_gap = -1032.11
# Duality_gap / Duality_gap_init = -3.44036
#
# Iterations number: 8200
# Inner iterations number: 16432
# Primal_func_value = 3000
# Dual_func_value = -4331.53
# Duality_gap = -1031.53
# Duality_gap / Duality_gap_init = -3.43844
#
# Iterations number: 8400
# Inner iterations number: 16832
# Primal_func_value = 3000
# Dual_func_value = -4330.96
# Duality_gap = -1030.96
# Duality_gap / Duality_gap_init = -3.43653
#
# Iterations number: 8600
# Inner iterations number: 17232
# Primal_func_value = 3000
# Dual_func_value = -4330.38
# Duality_gap = -1030.38
# Duality_gap / Duality_gap_init = -3.43461
#
# Iterations number: 8800
# Inner iterations number: 17632
# Primal_func_value = 3000
# Dual_func_value = -4329.81
# Duality_gap = -1029.81
# Duality_gap / Duality_gap_init = -3.4327
#
# Iterations number: 9000
# Inner iterations number: 18032
# Primal_func_value = 3000
# Dual_func_value = -4329.23
# Duality_gap = -1029.23
# Duality_gap / Duality_gap_init = -3.43077
#
# Iterations number: 9200
# Inner iterations number: 18432
# Primal_func_value = 3000
# Dual_func_value = -4328.66
# Duality_gap = -1028.66
# Duality_gap / Duality_gap_init = -3.42885
#
# Iterations number: 9400
# Inner iterations number: 18832
# Primal_func_value = 3000
# Dual_func_value = -4328.08
# Duality_gap = -1028.08
# Duality_gap / Duality_gap_init = -3.42692
# Iterations number: 9600
# Inner iterations number: 19232
# Primal_func_value = 3000
# Dual_func_value = -4327.5
# Duality_gap = -1027.5
# Duality_gap / Duality_gap_init = -3.425
#
# Iterations number: 9800
# Inner iterations number: 19632
# Primal_func_value = 3000
# Dual_func_value = -4326.92
# Duality_gap = -1026.92
# Duality_gap / Duality_gap_init = -3.42306
#
# Iterations number: 10000
# Inner iterations number: 20032
# Primal_func_value = 3000
# Dual_func_value = -4326.34
# Duality_gap = -1026.34
# Duality_gap / Duality_gap_init = -3.42113
#
# Iterations number: 10200
# Inner iterations number: 20432
# Primal_func_value = 3000
# Dual_func_value = -4325.76
# Duality_gap = -1025.76
# Duality_gap / Duality_gap_init = -3.41919
#
# Iterations number: 10400
# Inner iterations number: 20832
# Primal_func_value = 3000
# Dual_func_value = -4325.18
# Duality_gap = -1025.18
# Duality_gap / Duality_gap_init = -3.41726
#
# Iterations number: 10600
# Inner iterations number: 21232
# Primal_func_value = 3000
# Dual_func_value = -4324.59
# Duality_gap = -1024.59
# Duality_gap / Duality_gap_init = -3.41531
#
# Iterations number: 10800
# Inner iterations number: 21632
# Primal_func_value = 3000
# Dual_func_value = -4324.01
# Duality_gap = -1024.01
# Duality_gap / Duality_gap_init = -3.41337
#
# Iterations number: 11000
# Inner iterations number: 22032
# Primal_func_value = 3000
# Dual_func_value = -4323.43
# Duality_gap = -1023.43
# Duality_gap / Duality_gap_init = -3.41142
#
# Iterations number: 11200
# Inner iterations number: 22432
# Primal_func_value = 3000
# Dual_func_value = -4322.84
# Duality_gap = -1022.84
# Duality_gap / Duality_gap_init = -3.40947
#
# Iterations number: 11400
# Inner iterations number: 22832
# Primal_func_value = 3000
# Dual_func_value = -4322.26
# Duality_gap = -1022.26
# Duality_gap / Duality_gap_init = -3.40752
#
# Iterations number: 11600
# Inner iterations number: 23232
# Primal_func_value = 3000
# Dual_func_value = -4321.67
# Duality_gap = -1021.67
# Duality_gap / Duality_gap_init = -3.40557
#
# Iterations number: 11800
# Inner iterations number: 23632
# Primal_func_value = 3000
# Dual_func_value = -4321.08
# Duality_gap = -1021.08
# Duality_gap / Duality_gap_init = -3.40361
#
# Iterations number: 12000
# Inner iterations number: 24032
# Primal_func_value = 3000
# Dual_func_value = -4320.5
# Duality_gap = -1020.5
# Duality_gap / Duality_gap_init = -3.40165
#
# Iterations number: 12200
# Inner iterations number: 24432
# Primal_func_value = 3000
# Dual_func_value = -4319.91
# Duality_gap = -1019.91
# Duality_gap / Duality_gap_init = -3.39969
#
# Iterations number: 12400
# Inner iterations number: 24832
# Primal_func_value = 3000
# Dual_func_value = -4319.32
# Duality_gap = -1019.32
# Duality_gap / Duality_gap_init = -3.39773
#
# Iterations number: 12600
# Inner iterations number: 25232
# Primal_func_value = 3000
# Dual_func_value = -4318.73
# Duality_gap = -1018.73
# Duality_gap / Duality_gap_init = -3.39576
#
# Iterations number: 12800
# Inner iterations number: 25632
# Primal_func_value = 3000
# Dual_func_value = -4318.14
# Duality_gap = -1018.14
# Duality_gap / Duality_gap_init = -3.39379
#
# Iterations number: 13000
# Inner iterations number: 26032
# Primal_func_value = 3000
# Dual_func_value = -4317.55
# Duality_gap = -1017.55
# Duality_gap / Duality_gap_init = -3.39182
#
# Iterations number: 13200
# Inner iterations number: 26432
# Primal_func_value = 3000
# Dual_func_value = -4316.95
# Duality_gap = -1016.95
# Duality_gap / Duality_gap_init = -3.38984
#
# Iterations number: 13400
# Inner iterations number: 26832
# Primal_func_value = 3000
# Dual_func_value = -4316.36
# Duality_gap = -1016.36
# Duality_gap / Duality_gap_init = -3.38787
#
# Iterations number: 13600
# Inner iterations number: 27232
# Primal_func_value = 3000
# Dual_func_value = -4315.77
# Duality_gap = -1015.77
# Duality_gap / Duality_gap_init = -3.38589
#
# Iterations number: 13800
# Inner iterations number: 27632
# Primal_func_value = 3000
# Dual_func_value = -4315.17
# Duality_gap = -1015.17
# Duality_gap / Duality_gap_init = -3.38391
#
# Iterations number: 14000
# Inner iterations number: 28032
# Primal_func_value = 3000
# Dual_func_value = -4314.58
# Duality_gap = -1014.58
# Duality_gap / Duality_gap_init = -3.38192
#
# Iterations number: 14200
# Inner iterations number: 28432
# Primal_func_value = 3000
# Dual_func_value = -4313.98
# Duality_gap = -1013.98
# Duality_gap / Duality_gap_init = -3.37994
#
# Iterations number: 14400
# Inner iterations number: 28832
# Primal_func_value = 3000
# Dual_func_value = -4313.38
# Duality_gap = -1013.38
# Duality_gap / Duality_gap_init = -3.37795
#
# Iterations number: 14600
# Inner iterations number: 29232
# Primal_func_value = 3000
# Dual_func_value = -4312.79
# Duality_gap = -1012.79
# Duality_gap / Duality_gap_init = -3.37596
#
# Iterations number: 14800
# Inner iterations number: 29632
# Primal_func_value = 3000
# Dual_func_value = -4312.19
# Duality_gap = -1012.19
# Duality_gap / Duality_gap_init = -3.37396
#
# Iterations number: 15000
# Inner iterations number: 30032
# Primal_func_value = 3000
# Dual_func_value = -4311.59
# Duality_gap = -1011.59
# Duality_gap / Duality_gap_init = -3.37197
#
# Iterations number: 15200
# Inner iterations number: 30432
# Primal_func_value = 3000
# Dual_func_value = -4310.99
# Duality_gap = -1010.99
# Duality_gap / Duality_gap_init = -3.36997
#
# Iterations number: 15400
# Inner iterations number: 30832
# Primal_func_value = 3000
# Dual_func_value = -4310.39
# Duality_gap = -1010.39
# Duality_gap / Duality_gap_init = -3.36796
#
# Iterations number: 15600
# Inner iterations number: 31232
# Primal_func_value = 3000
# Dual_func_value = -4309.79
# Duality_gap = -1009.79
# Duality_gap / Duality_gap_init = -3.36596
#
# Iterations number: 15800
# Inner iterations number: 31632
# Primal_func_value = 3000
# Dual_func_value = -4309.19
# Duality_gap = -1009.19
# Duality_gap / Duality_gap_init = -3.36395
#
# Iterations number: 16000
# Inner iterations number: 32032
# Primal_func_value = 3000
# Dual_func_value = -4308.58
# Duality_gap = -1008.58
# Duality_gap / Duality_gap_init = -3.36195
#
# Iterations number: 16200
# Inner iterations number: 32432
# Primal_func_value = 3000
# Dual_func_value = -4307.98
# Duality_gap = -1007.98
# Duality_gap / Duality_gap_init = -3.35993
#
# Iterations number: 16400
# Inner iterations number: 32832
# Primal_func_value = 3000
# Dual_func_value = -4307.38
# Duality_gap = -1007.38
# Duality_gap / Duality_gap_init = -3.35792
#
# Iterations number: 16600
# Inner iterations number: 33232
# Primal_func_value = 3000
# Dual_func_value = -4306.77
# Duality_gap = -1006.77
# Duality_gap / Duality_gap_init = -3.3559
#
# Iterations number: 16800
# Inner iterations number: 33632
# Primal_func_value = 3000
# Dual_func_value = -4306.17
# Duality_gap = -1006.17
# Duality_gap / Duality_gap_init = -3.35388
#
# Iterations number: 17000
# Inner iterations number: 34032
# Primal_func_value = 3000
# Dual_func_value = -4305.56
# Duality_gap = -1005.56
# Duality_gap / Duality_gap_init = -3.35186
#
# Iterations number: 17200
# Inner iterations number: 34432
# Primal_func_value = 3000
# Dual_func_value = -4304.95
# Duality_gap = -1004.95
# Duality_gap / Duality_gap_init = -3.34984
#
# Iterations number: 17400
# Inner iterations number: 34832
# Primal_func_value = 3000
# Dual_func_value = -4304.34
# Duality_gap = -1004.34
# Duality_gap / Duality_gap_init = -3.34781
#
# Iterations number: 17600
# Inner iterations number: 35232
# Primal_func_value = 3000
# Dual_func_value = -4303.74
# Duality_gap = -1003.74
# Duality_gap / Duality_gap_init = -3.34578
#
# Iterations number: 17800
# Inner iterations number: 35632
# Primal_func_value = 3000
# Dual_func_value = -4303.13
# Duality_gap = -1003.13
# Duality_gap / Duality_gap_init = -3.34375
#
# Iterations number: 18000
# Inner iterations number: 36032
# Primal_func_value = 3000
# Dual_func_value = -4302.52
# Duality_gap = -1002.52
# Duality_gap / Duality_gap_init = -3.34172
#
# Iterations number: 18200
# Inner iterations number: 36432
# Primal_func_value = 3000
# Dual_func_value = -4301.91
# Duality_gap = -1001.91
# Duality_gap / Duality_gap_init = -3.33968
#
# Iterations number: 18400
# Inner iterations number: 36832
# Primal_func_value = 3000
# Dual_func_value = -4301.29
# Duality_gap = -1001.29
# Duality_gap / Duality_gap_init = -3.33765
#
# Iterations number: 18600
# Inner iterations number: 37232
# Primal_func_value = 3000
# Dual_func_value = -4300.68
# Duality_gap = -1000.68
# Duality_gap / Duality_gap_init = -3.3356
#
# Iterations number: 18800
# Inner iterations number: 37632
# Primal_func_value = 3000
# Dual_func_value = -4300.07
# Duality_gap = -1000.07
# Duality_gap / Duality_gap_init = -3.33356
#
# Iterations number: 19000
# Inner iterations number: 38032
# Primal_func_value = 3000
# Dual_func_value = -4299.45
# Duality_gap = -999.455
# Duality_gap / Duality_gap_init = -3.33152
# Iterations number: 19200
# Inner iterations number: 38432
# Primal_func_value = 3000
# Dual_func_value = -4298.84
# Duality_gap = -998.84
# Duality_gap / Duality_gap_init = -3.32947
#
# Iterations number: 19400
# Inner iterations number: 38832
# Primal_func_value = 3000
# Dual_func_value = -4298.22
# Duality_gap = -998.225
# Duality_gap / Duality_gap_init = -3.32742
#
# Iterations number: 19600
# Inner iterations number: 39232
# Primal_func_value = 3000
# Dual_func_value = -4297.61
# Duality_gap = -997.609
# Duality_gap / Duality_gap_init = -3.32536
#
# Iterations number: 19800
# Inner iterations number: 39632
# Primal_func_value = 3000
# Dual_func_value = -4296.99
# Duality_gap = -996.992
# Duality_gap / Duality_gap_init = -3.32331
#
# Iterations number: 20000
# Inner iterations number: 40032
# Primal_func_value = 3000
# Dual_func_value = -4296.37
# Duality_gap = -996.375
# Duality_gap / Duality_gap_init = -3.32125
#
# Result: success
# Total iters: 20000
# Primal_func_value = 3000
# Dual_func_value = -4296.37
# Duality_gap = -996.375
# Duality_gap / Duality_gap_init = -3.32125
# Oracle elapsed time: 2740 sec
# Elapsed time: 2758 sec
# Time ratio = 2.135750060134714
# Flow excess = 0.9999999999999749

# %%
result.keys()
# Out:
# dict_keys(['times', 'flows', 'iter_num', 'res_msg', 'history', 'zone travel times', 'elapsed_time'])

# %%
result['zone travel times'], result['elapsed_time'], result['times']
# Out:
# ({(1, 1): 0.0, (1, 2): 1.0, (2, 2): 0.0, (2, 1): 1.0},
#  2758.261487007141,
#  array([1.        , 1.06787503, 1.        , 1.06787503]))

# %%
base_flows
# Out:
# array([  -0., 3000.,   -0., 3000.])

# %%
#with open(sd_save + 'anaheim_' + 
# 'ustm' + '_base_flows_max_iter_' + str(max_iter) + '_SD.pickle', 'wb') as f:
#    pickle.dump(base_flows, f)

# %% [markdown]
# ## Model

# %% [raw]
# with open(sd_save + 'anaheim_' +
#           'ustm' + '_base_flows_max_iter_' +
#           str(1000) + '_SD.pickle', 'rb') as f:
#     base_flows = pickle.load(f)

# %%
base_flows = np.array([150, 100, 100, 100])
# base_flows = result['flows']
print(type(result['flows']))
epsilons = np.logspace(2,0,9)
epsilons
# Out:
# <class 'numpy.ndarray'>
# array([100.        ,  56.23413252,  31.6227766 ,  17.7827941 ,
#         10.        ,   5.62341325,   3.16227766,   1.77827941,
#          1.        ])

# %%
# graph_data['graph_table']['capacity'] = init_capacities
model = md.Model(graph_data, graph_correspondences,
                 total_od_flow, mu = 0)

graph_data['graph_table'].head()
# Out:
#    init_node  init_node_thru  term_node  term_node_thru  capacity  \
# 0          1            True          2            True    1500.0
# 1          1            True          2            True    1500.0
# 2          2            True          1            True    1500.0
# 3          2            True          1            True    1500.0
#
#    free_flow_time
# 0             1.0
# 1             0.5
# 2             1.0
# 3             0.5

# %% [markdown]
# ## Universal Similar Triangles

# %%
assert(model.mu == 0)
max_iter = 40000
for index, eps_abs in enumerate(epsilons):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter, 'stop_crit': 'dual_gap',
                     'verbose': True, 'verbose_step': 2000, 'save_history': True}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ustm', composite = True,
                                    solver_kwargs = solver_kwargs, 
                                    base_flows = base_flows)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    print('Time ratio =', 
          np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
    print('Flow excess =', 
          np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, 
          end = '\n\n')

    result['eps_abs'] = eps_abs
    result['elapsed_time'] = toc - tic
#     with open(sd_save + 'anaheim_result_' 
#               + 'ustm' + '_eps_abs_' + str(index) + '_SD.pickle', 'wb') as f:
#         pickle.dump(result, f)
# Out:
# eps_abs = 100.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 56.23413251903491
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 31.622776601683793
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 17.78279410038923
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 10.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 5.623413251903491
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 3.1622776601683795
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 1.7782794100389228
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 1.0
# Composite optimization...
# Oracles created...
# Universal similar triangles method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0

# %%
result['flows']
# Out:
# array([  -0., 3000.,   -0., 3000.])

# %%
#index += 9
epsilons = [300, 200]

# %% [markdown]
# ## Universal Gradient Descent

# %%
#weighted t added
assert(model.mu == 0)
max_iter = 40000
for index, eps_abs in enumerate(epsilons):
    print('eps_abs =', eps_abs)
    solver_kwargs = {'eps_abs': eps_abs,
                     'max_iter': max_iter, 'stop_crit': 'dual_gap',
                     'verbose': True, 'verbose_step': 2000, 'save_history': True}
    tic = time.time()
    result = model.find_equilibrium(solver_name = 'ugd', composite = True,
                                    solver_kwargs = solver_kwargs, 
                                    base_flows = base_flows)
    toc = time.time()
    print('Elapsed time: {:.0f} sec'.format(toc - tic))
    print('Time ratio =', 
          np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
    print('Flow excess =', 
          np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, 
          end = '\n\n')
    
    result['eps_abs'] = eps_abs
    result['elapsed_time'] = toc - tic
#     with open(sd_save + 'anaheim_result_' 
#         + 'ugd' + '_eps_abs_' + str(index) + '_SD.pickle', 'wb') as f:
#         pickle.dump(result, f)
# Out:
# eps_abs = 300
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0
#
# eps_abs = 200
# Composite optimization...
# Oracles created...
# Universal gradient descent method...
# Primal_init = 3000
# Dual_init = -3000
# Duality_gap_init = -1394.74
#
# Result: success
# Total iters: 1
# Primal_func_value = 3000
# Dual_func_value = -3306.19
# Duality_gap = -1700.92
# Duality_gap / Duality_gap_init = 1.21953
# Oracle elapsed time: 0 sec
# Elapsed time: 0 sec
# Time ratio = 1.2041241452319316
# Flow excess = 1.0

# %%
result['flows']
# Out:
# array([  -0., 3000.,   -0., 3000.])

# %%
#index += 9
#epsilons = [300, 200]

# %% [markdown]
# ## Weighted Dual Averages

# %% [markdown]
# ### Composite optimization

# %%
assert(model.mu == 0)
max_iter = 50000
solver_kwargs = {'max_iter': max_iter, 'stop_crit': 'max_iter',
                 'verbose': True, 'verbose_step': 4000, 'save_history': True}
tic = time.time()
result = model.find_equilibrium(solver_name = 'wda', composite = True, 
                                solver_kwargs = solver_kwargs, base_flows = base_flows)
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')

result['elapsed_time'] = toc - tic
with open(sd_save + 'anaheim_result_' + 'wda' + '_max_iter_' + str(max_iter) + '_SD.pickle', 'wb') as f:
    pickle.dump(result, f)

# %% [markdown]
# ### Non-composite optimization

# %%
assert(model.mu == 0)
max_iter = 50000
solver_kwargs = {'max_iter': max_iter, 'stop_crit': 'max_iter',
                 'verbose': True, 'verbose_step': 4000, 'save_history': True}
tic = time.time()
result = model.find_equilibrium(solver_name = 'wda', composite = False, 
                                solver_kwargs = solver_kwargs, base_flows = base_flows)
toc = time.time()
print('Elapsed time: {:.0f} sec'.format(toc - tic))
print('Time ratio =', np.max(result['times'] / graph_data['graph_table']['free_flow_time']))
print('Flow excess =', np.max(result['flows'] / graph_data['graph_table']['capacity']) - 1, end = '\n\n')

result['elapsed_time'] = toc - tic
with open(sd_save + 'anaheim_result_' + 'wda_noncomposite' + '_max_iter_' + str(max_iter) + '_SD.pickle', 'wb') as f:
    pickle.dump(result, f)

# %% [markdown]
# ## Plots

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pickle
import numpy as np
sd_save = 'stable_dynamics_results/'

# %%
"""
for method in ['ustm', 'ugd']:
    results = []
    i = 0
    while True:
        try:
            with open(sd_save + 'anaheim_result_' + method + '_eps_abs_'
                      + str(i) + '_SD.pickle', 'rb') as f:
                result = pickle.load(f)
                results.append(result) 
        except FileNotFoundError:
            break
        i += 1
    results.sort(key = lambda res : res['eps_abs'])
    
    for i, result in enumerate(results):
        with open(sd_save + 'anaheim_result_' + method + '_eps_abs_' 
                  + str(i) + '_SD.pickle', 'wb') as f:
            pickle.dump(result, f)
"""

# %%
results = {}

for method in ['ustm', 'ugd']:
    results[method] = {}
    results[method]['iters'] = []
    results[method]['inner_iters'] = []
    results[method]['epsilon'] = []
    results[method]['dual_gap_init'] = []
    i = 0
    while True:
        try:
            with open(sd_save + 'anaheim_result_' + method + '_eps_abs_'
                      + str(i) + '_SD.pickle', 'rb') as f:
                result = pickle.load(f)
                results[method]['epsilon'].append(result['eps_abs'])
                results[method]['iters'].append(result['iter_num'])
                results[method]['inner_iters'].append(result['history'].get('inner_iters')[-1])
                results[method]['dual_gap_init'].append(result['history'].get('dual_gap')[0])
        except FileNotFoundError:
            break
        i += 1

# %%
for method in ['wda', 'wda_noncomposite']:
    results[method] = {}
    with open(sd_save + 'anaheim_result_' + method + '_max_iter_50000_SD.pickle', 'rb') as f:
        result = pickle.load(f)
        results[method]['epsilon'] = result['history'].get('dual_gap')
        results[method]['iters'] = result['history'].get('iter')
        results[method]['dual_gap_init'] = result['history'].get('dual_gap')[0]

# %%
plt.figure(figsize=(7,4))
#plt.title('Convergence for Stable Dynamics model', fontsize=20)
for method, data in results.items():
    x = 1. / np.array(data['epsilon'])
    if 'inner_iters' in data:
        y = np.array(data['inner_iters'])
    else:
        y = np.array(data['iters'])
    plt.plot(x, y, label = method)
plt.legend(prop = {'size' : 11})
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'1 / $\varepsilon$', fontsize = 14)
plt.ylabel('inner iterations', fontsize = 14)
#plt.savefig('SD_convergence_1.jpg', dpi = 300)
plt.show()

# %%
#inner iterations vs relative accuracy = eps_abs / dual_gap_init
plt.figure(figsize=(7,4))

method_names = {'ustm' : 'UMST', 'ugd' : 'UGM', 'wda' : 'WDA',
                'wda_noncomposite' : 'non-composite WDA'}
for method, data in results.items():
    x = 1. / (np.array(data['epsilon']) / np.array(data['dual_gap_init']))
    if 'inner_iters' in data:
        y = np.array(data['inner_iters'])
    else:
        y = np.array(data['iters'])
    plt.plot(x, y, label = method_names[method])
plt.legend(prop = {'size' : 11})
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'1 / $\tilde\varepsilon$', fontsize = 14)
plt.ylabel('inner iterations', fontsize = 14)
#plt.savefig('sd_convergence_rel_eps.jpg', dpi = 300)
plt.show()
